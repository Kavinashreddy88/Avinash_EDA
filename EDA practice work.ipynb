# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
path=r'C:\Users\reddy\Naresh IT\Data Science\python classes\EDA\visadataset.csv'
visa_df=pd.read_csv(path)
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['education_of_employee']
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df[['education_of_employee']]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df.education_of_employee
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
cols=['education_of_employee']
visa_df[cols]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
set(visa_df['education_of_employee'].unique())
# Out:
# {"Bachelor's", 'Doctorate', 'High School', "Master's"}

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %%
con=visa_df['education_of_employee']=='High School'
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 11        EZYV12           Asia           High School                  Y
# 15        EZYV16           Asia           High School                  Y
# 23        EZYV24  North America           High School                  N
# 27        EZYV28           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25463  EZYV25464           Asia           High School                  N
# 25465  EZYV25466  North America           High School                  N
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
len(visa_df[con])
# Out:
# 3420

# %%
con=visa_df['education_of_employee']=='Doctorate'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 9         EZYV10    Europe             Doctorate                  Y
# 19        EZYV20      Asia             Doctorate                  N
# 24        EZYV25    Europe             Doctorate                  Y
# 31        EZYV32      Asia             Doctorate                  Y
# 42        EZYV43    Europe             Doctorate                  Y
# ...          ...       ...                   ...                ...
# 25407  EZYV25408      Asia             Doctorate                  Y
# 25426  EZYV25427    Europe             Doctorate                  N
# 25428  EZYV25429      Asia             Doctorate                  Y
# 25448  EZYV25449    Europe             Doctorate                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 9                         N             2251         1995
# ...

# %%
con=visa_df['education_of_employee']=="Bachelor's"
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 8         EZYV09           Asia            Bachelor's                  N
# ...          ...            ...                   ...                ...
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con=visa_df['education_of_employee']=="Master's"
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 1         EZYV02           Asia              Master's                  Y
# 4         EZYV05         Africa              Master's                  Y
# 5         EZYV06           Asia              Master's                  Y
# 10        EZYV11           Asia              Master's                  N
# 14        EZYV15           Asia              Master's                  Y
# ...          ...            ...                   ...                ...
# 25467  EZYV25468  North America              Master's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
unique_labels=visa_df['education_of_employee'].unique()
for i in unique_labels:
    con=visa_df['education_of_employee']==i
    print(i,':',len( visa_df[con]))
# Out:
# High School : 3420
# Master's : 9634
# Bachelor's : 10234
# Doctorate : 2192

# %%
unique_labels=visa_df['education_of_employee'].unique()
count=[]
for i in unique_labels:
    con=visa_df['education_of_employee']==i
    count.append(len(visa_df[con]))
    
pcontinent_df=pd.DataFrame(zip(unique_labels,count),columns=['continent','count'])

# %% [markdown]
# FREQUENCY TABLE:

# %%
continent_df=pd.DataFrame(zip(unique_labels,count),columns=['continent','count'])
contcinent_df
# Out:
#      continent  count
# 0  High School   3420
# 1     Master's   9634
# 2   Bachelor's  10234
# 3    Doctorate   2192

# %%
continent_df.to_csv('output.csv')

# %%
continent_df.to_csv('output.csv',index=False)

# %%
visa_df
visa_df['education_of_employee']=="Master's"
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 25475    False
# 25476    False
# 25477     True
# 25478     True
# 25479    False
# Name: education_of_employee, Length: 25480, dtype: bool

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %% [markdown]
# BAR-CHART:

# %%
path=r'C:\Users\reddy\Naresh IT\Data Science\python classes\EDA\visadataset.csv'
visa_df=pd.read_csv(path)
continent_vc=visa_df['education_of_employee'].value_counts()
l1=continent_vc.keys()
l2=continent_vc.values
continent_vc_df=pd.DataFrame(zip(l1,l2),columns=['education_of_employee','count'])
continent_vc_df
# Out:
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192

# %%
plt.figure(figsize=(10,6)) 
plt.bar('education_of_employee','count',data=continent_vc_df)
plt.xlabel('education_of_employee')
plt.ylabel('count')
plt.title('Bar Chart of education_of_employee and their count')
plt.savefig('Datascience.jpg')
plt.show()

# %%
visa_df['education_of_employee'].value_counts().keys()
# Out:
# Index(['Bachelor's', 'Master's', 'High School', 'Doctorate'], dtype='object', name='education_of_employee')

# %%
plt.figure(figsize=(10,6))
l=visa_df['education_of_employee'].value_counts().keys() 
sns.countplot(data=visa_df,x='education_of_employee',order=l)
plt.xlabel('education_of_employee')
plt.ylabel('count')
plt.title('Bar Chart of education_of_employee and their count')
plt.savefig('Datascience.jpg')
plt.show()
